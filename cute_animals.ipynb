# %%
from utils import *
from fastai2.vision.widgets import *

# %%
path = Path()
learn_inf = load_learner(path/'export.pkl')

# %%
btn_upload = widgets.FileUpload()
btn_run = widgets.Button(description='Classify')
out_pl = widgets.Output()
out_pl.clear_output()
lbl_pred = widgets.Label()

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %% [markdown]
# ## Tarsier, Bushbaby, Aye-Aye classifier
#
# #### This classifier helps you identify the extremely cute bushbaby and tarsier from the actually-quite-scary aye-aye!
# #### It was inspired by the O'Reilly animals series, in particular this cover:

# %%
oreilly_img = PILImage.create("velocityny2016_tarsier.png")
display(oreilly_img)
# Out:
# PILImage mode=RGB size=178x200

# %% [markdown]
# Many people may find it difficult to distinguish between these animals in the wild so here is a handy app for the next time you are on safari!

# %%
icon_img = PILImage.create("icon.png")
display(icon_img.to_thumb(128,128))
# Out:
# <PIL.Image.Image image mode=RGB size=128x105 at 0x12F650978>

# %%
VBox([widgets.Label('Select your animal!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
